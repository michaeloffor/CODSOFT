# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
print('all libraries imported')
# Out:
# all libraries imported

# %%
#reading the dataset into dataframe
df_data = pd.read_csv('creditcard.csv')
df_data.head(20)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# 13  11.0  1.069374  0.287722  0.828613  2.712520 -0.178398  0.337544
# 14  12.0 -2.791855 -0.327771  1.641750  1.767473 -0.136588  0.807596
# 15  12.0 -0.752417  0.345485  2.057323 -1.468643 -1.158394 -0.077850
# 16  12.0  1.103215 -0.040296  1.267332  1.289091 -0.735997  0.288069
# 17  13.0 -0.436905  0.918966  0.924591 -0.727219  0.915679 -0.127867
# 18  14.0 -5.401258 -5.450148  1.186305  1.736239  3.049106 -1.763406
# 19  15.0  1.492936 -1.029346  0.454795 -1.438026 -1.555434 -0.720961
#
#           V7        V8        V9  ...       V21       V22       V23       V24  \
# 0   0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1  -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2   0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3   0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4   0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
# 5   0.476201  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427
# 6  -0.005159  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055
# 7   1.120631 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709
# 8   0.370145  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592
# 9   0.651583  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050
# 10 -1.423236  0.048456 -1.720408  ... -0.009302  0.313894  0.027740  0.500512
# 11  0.470455  0.538247 -0.558895  ...  0.049924  0.238422  0.009130  0.996710
# 12 -0.689405 -0.227487 -2.094011  ... -0.231809 -0.483285  0.084668  0.392831
# 13 -0.096717  0.115982 -0.221083  ... -0.036876  0.074412 -0.071407  0.104744
# 14 -0.422911 -1.907107  0.755713  ...  1.151663  0.222182  1.020586  0.028317
# 15 -0.608581  0.003603 -0.436167  ...  0.499625  1.353650 -0.256573 -0.065084
# 16 -0.586057  0.189380  0.782333  ... -0.024612  0.196002  0.013802  0.103758
# 17  0.707642  0.087962 -0.665271  ... -0.194796 -0.672638 -0.156858 -0.888386
# 18 -1.559738  0.160842  1.233090  ... -0.503600  0.984460  2.458589  0.042119
# 19 -1.080664 -0.053127 -1.978682  ... -0.177650 -0.175074  0.040002  0.295814
#
#          V25       V26       V27       V28  Amount  Class
# 0   0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1   0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2  -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3   0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4  -0.206010  0.502292  0.219422  0.215153   69.99      0
# 5  -0.232794  0.105915  0.253844  0.081080    3.67      0
# 6   0.750137 -0.257237  0.034507  0.005168    4.99      0
# 7  -0.415267 -0.051634 -1.206921 -1.085339   40.80      0
# 8   0.373205 -0.384157  0.011747  0.142404   93.20      0
# 9  -0.069733  0.094199  0.246219  0.083076    3.68      0
# 10  0.251367 -0.129478  0.042850  0.016253    7.80      0
# 11 -0.767315 -0.492208  0.042472 -0.054337    9.99      0
# 12  0.161135 -0.354990  0.026416  0.042422  121.50      0
# 13  0.548265  0.104094  0.021491  0.021293   27.50      0
# 14 -0.232746 -0.235557 -0.164778 -0.030154   58.80      0
# 15 -0.039124 -0.087086 -0.180998  0.129394   15.99      0
# 16  0.364298 -0.382261  0.092809  0.037051   12.99      0
# 17 -0.342413 -0.049027  0.079692  0.131024    0.89      0
# 18 -0.481631 -0.621272  0.392053  0.949594   46.80      0
# 19  0.332931 -0.220385  0.022298  0.007602    5.00      0
#
# [20 rows x 31 columns]

# %%
#checking the values and their count in Class column
df_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#getting number of rows and columns
df_data.shape
# Out:
# (284807, 31)

# %%
#checking the datatypes and how many they are
df_data.dtypes.value_counts()
# Out:
# float64    30
# int64       1
# Name: count, dtype: int64

# %%
#checking for any columns with null values
df_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# 14  0.680590  0.386050  0.564842  0.386971  0.413470  0.312512
# 15  0.661623  0.373464  0.575710  0.411223  0.413170  0.315750
# 16  0.665639  0.396216  0.598355  0.363007  0.418224  0.313876
# 17  0.663104  0.262525  0.558686  0.417440  0.417982  0.315783
# 18  0.701946  0.387910  0.550871  0.323965  0.423747  0.332394
# 19  0.666028  0.422095  0.596595  0.389449  0.416923  0.313278
# 20  0.664678  0.341241  0.581948  0.356477  0.418109  0.314412
# 21  0.664713  0.197376  0.599844  0.458112  0.416813  0.312827
# 22  0.663891  0.332321  0.611766  0.443181  0.415763  0.312892
# 23  0.662681  0.439243  0.623968  0.388265  0.422724  0.318207
# 24  0.678358  0.514750  0.595936  0.449893  0.429570  0.313420
# 25  0.676459  0.435937  0.591895  0.470272  0.423155  0.318060
# 26  0.663199  0.440856  0.618593  0.370387  0.416813  0.313733
# 27  0.664874  0.429013  0.609321  0.379685  0.417292  0.313709
# 28  0.664862  0.468814  0.567584  0.380125  0.419883  0.316222
# 29  0.665648  0.382632  0.594445  0.360914  0.418015  0.313615
# 30  0.664776  0.392902  0.606486  0.472633  0.416092  0.313364
#
# [31 rows x 28 columns]

# %% [markdown]
# All values in the V column has been normalized.

# %%
#splitting the dataset into features and target as x and y respectively dataset
x = df_data.drop('Class', axis=1)
y = df_data['Class']

# %%
#importing classification algorithm
from sklearn.linear_model import LogisticRegression

# %%
#importing train_test_split
from sklearn.model_selection import train_test_split

# Splitting the dataset into 80% training and 20% testing
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#training our algorithm
model = LogisticRegression(max_iter=350000)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

#importing metrics
from sklearn import metrics
print('Mean absolute:', round(metrics.mean_absolute_error(y_test, y_pred), 2))
print('Mean squared error:', round(metrics.mean_squared_error(y_test, y_pred), 2))
print('Root mean squared error:', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)), 2))
print('The accuracy score: ',round(metrics.accuracy_score(y_pred, y_test)*100, 2),  '%')
# Out:
# Mean absolute: 0.0
# Mean squared error: 0.0
# Root mean squared error: 0.03
# The accuracy score:  99.9 %

# %%
#using our model to make a prediction

input_data = [[15.0, -0.0183, 0.0538, -0.0403, 0.0159, 0.0166, 0.0389, -0.0061, -0.0013, 0.0192, 0.0171, 0.0066, 0.0101, -0.0031, 0.0089, -0.0175, 0.0069, 0.0007, 0.0108, 0.0038, 0.0082, 0.0017, 0.0049, 0.0015, 0.4567, 0.4635, 0.3654, 0.3763, 0.3736, 1364]]
data_array = np.asarray(input_data)
reshaped_data = data_array.reshape(1, -1)
prediction = model.predict(reshaped_data)
if prediction == 1:
    print('This transaction is fraudulent.')
else:
    print('This transaction is not fraudulent.')
# Out:
# This transaction is fraudulent.
# c:\Users\MY PC\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#evaluating our model using F1-score, recall and precision score

from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
f1_score(y_test, y_pred, average='macro')
print('The F1-score: ', round(f1_score(y_test, y_pred, average='macro')*100, 2),  '%')


recall_score(y_test, y_pred, average='macro')
print('The recall score: ', round(recall_score(y_test, y_pred, average='macro')*100, 2),  '%')


precision_score(y_test, y_pred, average='macro')
print('The precision score: ', round(precision_score(y_test, y_pred, average='macro')*100, 2),  '%')
# Out:
# The F1-score:  80.69 %
# The recall score:  73.97 %
# The precision score:  92.68 %
